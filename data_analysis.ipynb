# %%
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
df_company = pd.read_csv("./data/company_info.csv")
df_event = pd.read_csv("./data/event_info.csv")
df_people = pd.read_csv("./data/people_info.csv")

# %% [markdown]
# ## Analyzing Data

# %%
df_company.head(5)
# Out:
#                                     company_logo_url company_logo_text  \
# 0  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...  Women in Finance
# 1  https://media.licdn.com/dms/image/C4D0BAQHlTYA...              BBGC
# 2  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...       HR MARITIME
# 3  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...       HR MARITIME
# 4  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...  Kerry Consulting
#
#                   company_name relation_to_event  \
# 0         100 Women In Finance           partner
# 1                         BBGC           sponsor
# 2                  HR Maritime           partner
# 3  HR Maritime Consultants Ltd           partner
# 4             Kerry Consulting           sponsor
#
#                                 event_url company_revenue n_employees  \
# 0  https://apac.commoditytradingweek.com/             NaN       11-50
# 1  https://apac.commoditytradingweek.com/             NaN      51-200
# 2  https://apac.commoditytradingweek.com/      $2 million        2-10
# 3  https://apac.commoditytradingweek.com/      $6 million      51-200
# 4  https://apac.commoditytradingweek.com/     $12 million       114.0
#
#       company_phone  company_founding_year  \
# 0               NaN                 2001.0
# 1               NaN                    NaN
# 2  +41 22 732 57 00                 2008.0
# 3  +44 20 3514 0080                 2011.0
# 4    (656) 333-8530                 2003.0
#
#                                     company_address  \
# 0                                               NaN
# 1                                               NaN
# 2  1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH
# 3                                               NaN
# 4           6 Temasek Blvd 31, Singapore 038986, SG
#
#                 company_industry  \
# 0             Financial Services
# 1  IT Services and IT Consulting
# 2        Maritime Transportation
# 3                       Maritime
# 4        Staffing and Recruiting
#
#                                     company_overview  \
# 0  100 Women in Finance strengthens the global fi...
# 1  Business Benefits Global Consulting (BBGC) is ...
# 2  HR Maritime is a Geneva based company providin...
# 3  HR Maritime safeguards commercial shipping ves...
# 4  Kerry Consulting Information\nHeadquartered in...
#
#                        homepage_url  \
# 0      https://100women.org/events/
# 1              www.bbgcservices.com
# 2        http://www.hr-maritime.com
# 3         http://www.hrmaritime.com
# 4  https://www.kerryconsulting.com/
#
#                                 linkedin_company_url    homepage_base_url  \
# 0  https://www.linkedin.com/company/100-women-in-...         100women.org
# 1  https://it.linkedin.com/company/bbgcservices/a...     bbgcservices.com
# 2  https://ch.linkedin.com/company/hr-maritime/about      hr-maritime.com
# 3  https://at.linkedin.com/company/hr-maritime-co...       hrmaritime.com
# 4  https://mz.linkedin.com/company/kerry-consulti...  kerryconsulting.com
#
#                       company_logo_url_on_event_page company_logo_match_flag
# 0  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 1  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 2  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 3  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 4  https://apac.commoditytradingweek.com/wp-conte...                     yes

# %%
df_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   company_logo_url                606 non-null    object
#  1   company_logo_text               742 non-null    object
#  2   company_name                    742 non-null    object
#  3   relation_to_event               742 non-null    object
#  4   event_url                       742 non-null    object
#  5   company_revenue                 405 non-null    object
#  6   n_employees                     639 non-null    object
#  7   company_phone                   413 non-null    object
#  8   company_founding_year           576 non-null    float64
#  9   company_address                 374 non-null    object
#  10  company_industry                644 non-null    object
#  11  company_overview                613 non-null    object
#  12  homepage_url                    644 non-null    object
#  13  linkedin_company_url            493 non-null    object
#  14  homepage_base_url               742 non-null    object
#  15  company_logo_url_on_event_page  742 non-null    object
#  16  company_logo_match_flag         587 non-null    object
# dtypes: float64(1), object(16)
# memory usage: 98.7+ KB

# %%
df_event.head(5)
# Out:
#                                       event_logo_url  \
# 0  http://expo.overseaseducation.sg/v.fastcdn.co/...
# 1  https://ahiceconference.com/southeastasia/wp-c...
# 2  https://apac.commoditytradingweek.com/wp-conte...
# 3  https://architecturebuildingservices.com.sg/wp...
# 4  https://asiandownstreaminsights.com/wp-content...
#
#                                     event_name event_start_date  \
# 0               World University Expo @ SUNTEC       2024-07-06
# 1                        AHICE South East Asia       2025-02-25
# 2                  Commodity Trading Week APAC       2025-02-25
# 3  Architecture & Building Services (ABS) 2024       2024-11-13
# 4                      Asian Downstream Summit       2024-10-23
#
#   event_end_date                                        event_venue  \
# 0     2024-07-06                           SUNTEC Convention Centre
# 1     2025-02-26                              Pan Pacific Singapore
# 2     2025-02-26                                   Marina Bay Sands
# 3     2024-11-15  Marina Bay Sands Expo & Convention Centre Sing...
# 4     2024-10-24          Sands Expo & Convention Centre, Singapore
#
#   event_country                                  event_description  \
# 0           NaN  Join our World University Expo this Saturday, ...
# 1           NaN  The Asian Hotel Industry Conference & Exhibiti...
# 2           NaN  Commodity Trading Week APAC is the premier eve...
# 3           NaN  The 10th Architecture & Building Services (ABS...
# 4           NaN  The Asian Downstream Summit is Asia’s most inf...
#
#                                            event_url
# 0                  http://expo.overseaseducation.sg/
# 1         https://ahiceconference.com/southeastasia/
# 2             https://apac.commoditytradingweek.com/
# 3       https://architecturebuildingservices.com.sg/
# 4  https://asiandownstreaminsights.com/events/asi...

# %%
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_logo_url     72 non-null     object
#  1   event_name         72 non-null     object
#  2   event_start_date   72 non-null     object
#  3   event_end_date     70 non-null     object
#  4   event_venue        69 non-null     object
#  5   event_country      19 non-null     object
#  6   event_description  71 non-null     object
#  7   event_url          72 non-null     object
# dtypes: object(8)
# memory usage: 4.6+ KB

# %%
df_people.tail(5)
# Out:
#      first_name middle_name last_name  \
# 6455        Guo         NaN     Cosmo
# 6456      Alice         NaN    Hughes
# 6457    Giacomo         NaN  Ballabio
# 6458      kumar         NaN     rohit
# 6459      Almog         NaN     Cohen
#
#                                        job_title  person_city person_state  \
# 6455                              Sales Engineer  Qinhuangdao        Hebei
# 6456                   Event Marketing Executive    Leicester          NaN
# 6457                   Plant Logistic specialist        Turin          NaN
# 6458  Hospitality @ Swiss-Belhotel International    Jhunjhunu           RJ
# 6459                             CTO, Co-Founder          NaN          NaN
#
#      person_country   email_pattern   homepage_base_url  \
# 6455          China  [first].[last]       contecmed.com
# 6456             GB  [first].[last]       worldline.com
# 6457             IT             NaN   fptindustrial.com
# 6458             IN             NaN  swiss-belhotel.com
# 6459         Israel         [first]     sentinelone.com
#
#      duration_in_current_job duration_in_current_company
# 6455                     NaN                         NaN
# 6456                     NaN                         NaN
# 6457                     NaN                         NaN
# 6458                     NaN                         NaN
# 6459                     NaN                         NaN

# %%
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6460 entries, 0 to 6459
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   first_name                   6460 non-null   object
#  1   middle_name                  602 non-null    object
#  2   last_name                    6074 non-null   object
#  3   job_title                    6434 non-null   object
#  4   person_city                  5107 non-null   object
#  5   person_state                 3201 non-null   object
#  6   person_country               5977 non-null   object
#  7   email_pattern                3646 non-null   object
#  8   homepage_base_url            6460 non-null   object
#  9   duration_in_current_job      1026 non-null   object
#  10  duration_in_current_company  997 non-null    object
# dtypes: object(11)
# memory usage: 555.3+ KB

# %% [markdown]
# ## Merging DataFrames

# %%
df_company_event = pd.merge(df_company, df_event, on="event_url", how="inner")

# %%
df_company_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   company_logo_url                606 non-null    object
#  1   company_logo_text               742 non-null    object
#  2   company_name                    742 non-null    object
#  3   relation_to_event               742 non-null    object
#  4   event_url                       742 non-null    object
#  5   company_revenue                 405 non-null    object
#  6   n_employees                     639 non-null    object
#  7   company_phone                   413 non-null    object
#  8   company_founding_year           576 non-null    float64
#  9   company_address                 374 non-null    object
#  10  company_industry                644 non-null    object
#  11  company_overview                613 non-null    object
#  12  homepage_url                    644 non-null    object
#  13  linkedin_company_url            493 non-null    object
#  14  homepage_base_url               742 non-null    object
#  15  company_logo_url_on_event_page  742 non-null    object
#  16  company_logo_match_flag         587 non-null    object
#  17  event_logo_url                  742 non-null    object
#  18  event_name                      742 non-null    object
#  19  event_start_date                742 non-null    object
#  20  event_end_date                  742 non-null    object
#  21  event_venue                     742 non-null    object
#  22  event_country                   102 non-null    object
#  23  event_description               742 non-null    object
# dtypes: float64(1), object(23)
# memory usage: 139.3+ KB

# %%
df_company_event.head(5)
# Out:
#                                     company_logo_url company_logo_text  \
# 0  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...  Women in Finance
# 1  https://media.licdn.com/dms/image/C4D0BAQHlTYA...              BBGC
# 2  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...       HR MARITIME
# 3  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...       HR MARITIME
# 4  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...  Kerry Consulting
#
#                   company_name relation_to_event  \
# 0         100 Women In Finance           partner
# 1                         BBGC           sponsor
# 2                  HR Maritime           partner
# 3  HR Maritime Consultants Ltd           partner
# 4             Kerry Consulting           sponsor
#
#                                 event_url company_revenue n_employees  \
# 0  https://apac.commoditytradingweek.com/             NaN       11-50
# 1  https://apac.commoditytradingweek.com/             NaN      51-200
# 2  https://apac.commoditytradingweek.com/      $2 million        2-10
# 3  https://apac.commoditytradingweek.com/      $6 million      51-200
# 4  https://apac.commoditytradingweek.com/     $12 million       114.0
#
#       company_phone  company_founding_year  \
# 0               NaN                 2001.0
# 1               NaN                    NaN
# 2  +41 22 732 57 00                 2008.0
# 3  +44 20 3514 0080                 2011.0
# 4    (656) 333-8530                 2003.0
#
#                                     company_address  ...    homepage_base_url  \
# 0                                               NaN  ...         100women.org
# 1                                               NaN  ...     bbgcservices.com
# 2  1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH  ...      hr-maritime.com
# 3                                               NaN  ...       hrmaritime.com
# 4           6 Temasek Blvd 31, Singapore 038986, SG  ...  kerryconsulting.com
#
#                       company_logo_url_on_event_page company_logo_match_flag  \
# 0  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 1  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 2  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 3  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 4  https://apac.commoditytradingweek.com/wp-conte...                     yes
#
#                                       event_logo_url  \
# 0  https://apac.commoditytradingweek.com/wp-conte...
# 1  https://apac.commoditytradingweek.com/wp-conte...
# 2  https://apac.commoditytradingweek.com/wp-conte...
# 3  https://apac.commoditytradingweek.com/wp-conte...
# 4  https://apac.commoditytradingweek.com/wp-conte...
#
#                     event_name event_start_date event_end_date  \
# 0  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 1  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 2  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 3  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 4  Commodity Trading Week APAC       2025-02-25     2025-02-26
#
#         event_venue event_country  \
# 0  Marina Bay Sands           NaN
# 1  Marina Bay Sands           NaN
# 2  Marina Bay Sands           NaN
# 3  Marina Bay Sands           NaN
# 4  Marina Bay Sands           NaN
#
#                                    event_description
# 0  Commodity Trading Week APAC is the premier eve...
# 1  Commodity Trading Week APAC is the premier eve...
# 2  Commodity Trading Week APAC is the premier eve...
# 3  Commodity Trading Week APAC is the premier eve...
# 4  Commodity Trading Week APAC is the premier eve...
#
# [5 rows x 24 columns]

# %%
df_people_company = pd.merge(df_people, df_company, on="homepage_base_url", how="inner")

# %%
df_people_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   first_name                      7101 non-null   object
#  1   middle_name                     700 non-null    object
#  2   last_name                       6626 non-null   object
#  3   job_title                       7057 non-null   object
#  4   person_city                     5674 non-null   object
#  5   person_state                    3508 non-null   object
#  6   person_country                  6576 non-null   object
#  7   email_pattern                   3859 non-null   object
#  8   homepage_base_url               7101 non-null   object
#  9   duration_in_current_job         1026 non-null   object
#  10  duration_in_current_company     997 non-null    object
#  11  company_logo_url                7051 non-null   object
#  12  company_logo_text               7101 non-null   object
#  13  company_name                    7101 non-null   object
#  14  relation_to_event               7101 non-null   object
#  15  event_url                       7101 non-null   object
#  16  company_revenue                 5833 non-null   object
#  17  n_employees                     7081 non-null   object
#  18  company_phone                   6196 non-null   object
#  19  company_founding_year           6325 non-null   float64
#  20  company_address                 5517 non-null   object
#  21  company_industry                7081 non-null   object
#  22  company_overview                7061 non-null   object
#  23  homepage_url                    7081 non-null   object
#  24  linkedin_company_url            5557 non-null   object
#  25  company_logo_url_on_event_page  7101 non-null   object
#  26  company_logo_match_flag         6828 non-null   object
# dtypes: float64(1), object(26)
# memory usage: 1.5+ MB

# %%
df_people_company.head()
# Out:
#   first_name middle_name last_name                   job_title person_city  \
# 0    Cynthia         NaN   Battini              Indirect Buyer         NaN
# 1  Alexander         NaN   McClure            Public Relations      Austin
# 2  Alexander         NaN   McClure            Public Relations      Austin
# 3  Alexander         NaN   McClure            Public Relations      Austin
# 4      Nadir         NaN    Shaari  SEO Junior Account Manager      London
#
#   person_state person_country   email_pattern homepage_base_url  \
# 0          NaN         France             NaN      ariane.group
# 1           TX             US             NaN        amazon.com
# 2           TX             US             NaN        amazon.com
# 3           TX             US             NaN        amazon.com
# 4          NaN             GB  [first].[last]      artefact.com
#
#   duration_in_current_job  ...             n_employees      company_phone  \
# 0                     NaN  ...  5,001-10,000 employees  +33 5 57 20 86 25
# 1                     NaN  ...                 10,001+     (206) 266-1000
# 2                     NaN  ...                 10,001+     (206) 266-1000
# 3                     NaN  ...                 10,001+     (206) 266-1000
# 4                     NaN  ...   1,001-5,000 employees  +33 1 79 72 45 45
#
#   company_founding_year                                    company_address  \
# 0                2015.0  51-61 Route de Verneuil, Les Mureaux, Île-de-F...
# 1                2006.0       2127 7th Ave., Seattle, Washington 98109, US
# 2                2006.0       2127 7th Ave., Seattle, Washington 98109, US
# 3                2006.0       2127 7th Ave., Seattle, Washington 98109, US
# 4                2014.0      19 Rue Richer, Paris, Île-de-France 75009, FR
#
#                                  company_industry  \
# 0  Aviation and Aerospace Component Manufacturing
# 1                   IT Services and IT Consulting
# 2                   IT Services and IT Consulting
# 3                   IT Services and IT Consulting
# 4                Business Consulting and Services
#
#                                     company_overview  \
# 0  With roots reaching back more than 70 years in...
# 1  Launched in 2006, Amazon Web Services (AWS) be...
# 2  Launched in 2006, Amazon Web Services (AWS) be...
# 3  Launched in 2006, Amazon Web Services (AWS) be...
# 4  Artefact is a leading global consulting compan...
#
#                          homepage_url  \
# 0             http://www.ariane.group
# 1               http://aws.amazon.com
# 2               http://aws.amazon.com
# 3               http://aws.amazon.com
# 4  https://www.artefact.com/about-us/
#
#                                 linkedin_company_url  \
# 0  https://www.linkedin.com/company/arianegroup/a...
# 1  https://www.linkedin.com/company/amazon-web-se...
# 2  https://www.linkedin.com/company/amazon-web-se...
# 3  https://www.linkedin.com/company/amazon-web-se...
# 4  https://ae.linkedin.com/company/artefact-globa...
#
#                       company_logo_url_on_event_page  company_logo_match_flag
# 0  https://www.space.org.sg/gstc/wp-content/uploa...                      yes
# 1  https://terrapinn-cdn.com/tres/pa-images/10817...                      yes
# 2  https://taskfilescsm.s3.amazonaws.com:443/uplo...                      yes
# 3  https://www.industrial-transformation.com//con...                      yes
# 4  https://www.digitalmarketing-conference.com/as...                      yes
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Exporting Data as CSV files

# %%
df_company_event.to_csv("./data/company_event.csv", index=False, encoding="utf-8-sig")
df_people_company.to_csv("./data/people_company.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Reading LLM updated Data

# %%
df_processed_company_event = pd.read_csv("./data/company_event_with_industry.csv")

# %%
df_processed_company_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   company_logo_url                606 non-null    object
#  1   company_logo_text               742 non-null    object
#  2   company_name                    742 non-null    object
#  3   relation_to_event               742 non-null    object
#  4   event_url                       742 non-null    object
#  5   company_revenue                 405 non-null    object
#  6   n_employees                     639 non-null    object
#  7   company_phone                   413 non-null    object
#  8   company_founding_year           576 non-null    float64
#  9   company_address                 374 non-null    object
#  10  company_industry                644 non-null    object
#  11  company_overview                613 non-null    object
#  12  homepage_url                    644 non-null    object
#  13  linkedin_company_url            493 non-null    object
#  14  homepage_base_url               742 non-null    object
#  15  company_logo_url_on_event_page  742 non-null    object
#  16  company_logo_match_flag         587 non-null    object
#  17  event_logo_url                  742 non-null    object
#  18  event_name                      742 non-null    object
#  19  event_start_date                742 non-null    object
#  20  event_end_date                  742 non-null    object
#  21  event_venue                     742 non-null    object
#  22  event_country                   102 non-null    object
#  23  event_description               742 non-null    object
#  24  event_industry                  742 non-null    object
# dtypes: float64(1), object(24)
# memory usage: 145.1+ KB

# %%
df_processed_company_event.head()
# Out:
#                                     company_logo_url company_logo_text  \
# 0  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...  Women in Finance
# 1  https://media.licdn.com/dms/image/C4D0BAQHlTYA...              BBGC
# 2  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...       HR MARITIME
# 3  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...       HR MARITIME
# 4  https://d1hbpr09pwz0sk.cloudfront.net/logo_url...  Kerry Consulting
#
#                   company_name relation_to_event  \
# 0         100 Women In Finance           partner
# 1                         BBGC           sponsor
# 2                  HR Maritime           partner
# 3  HR Maritime Consultants Ltd           partner
# 4             Kerry Consulting           sponsor
#
#                                 event_url company_revenue n_employees  \
# 0  https://apac.commoditytradingweek.com/             NaN       11-50
# 1  https://apac.commoditytradingweek.com/             NaN      51-200
# 2  https://apac.commoditytradingweek.com/      $2 million        2-10
# 3  https://apac.commoditytradingweek.com/      $6 million      51-200
# 4  https://apac.commoditytradingweek.com/     $12 million       114.0
#
#       company_phone  company_founding_year  \
# 0               NaN                 2001.0
# 1               NaN                    NaN
# 2  +41 22 732 57 00                 2008.0
# 3  +44 20 3514 0080                 2011.0
# 4    (656) 333-8530                 2003.0
#
#                                     company_address  ...  \
# 0                                               NaN  ...
# 1                                               NaN  ...
# 2  1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH  ...
# 3                                               NaN  ...
# 4           6 Temasek Blvd 31, Singapore 038986, SG  ...
#
#                       company_logo_url_on_event_page company_logo_match_flag  \
# 0  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 1  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 2  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 3  https://apac.commoditytradingweek.com/wp-conte...                     yes
# 4  https://apac.commoditytradingweek.com/wp-conte...                     yes
#
#                                       event_logo_url  \
# 0  https://apac.commoditytradingweek.com/wp-conte...
# 1  https://apac.commoditytradingweek.com/wp-conte...
# 2  https://apac.commoditytradingweek.com/wp-conte...
# 3  https://apac.commoditytradingweek.com/wp-conte...
# 4  https://apac.commoditytradingweek.com/wp-conte...
#
#                     event_name event_start_date event_end_date  \
# 0  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 1  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 2  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 3  Commodity Trading Week APAC       2025-02-25     2025-02-26
# 4  Commodity Trading Week APAC       2025-02-25     2025-02-26
#
#         event_venue event_country  \
# 0  Marina Bay Sands           NaN
# 1  Marina Bay Sands           NaN
# 2  Marina Bay Sands           NaN
# 3  Marina Bay Sands           NaN
# 4  Marina Bay Sands           NaN
#
#                                    event_description event_industry
# 0  Commodity Trading Week APAC is the premier eve...        Finance
# 1  Commodity Trading Week APAC is the premier eve...        Finance
# 2  Commodity Trading Week APAC is the premier eve...        Finance
# 3  Commodity Trading Week APAC is the premier eve...        Finance
# 4  Commodity Trading Week APAC is the premier eve...        Finance
#
# [5 rows x 25 columns]

# %%
df_processed_company_people = pd.read_csv("./data/updated_people_company.csv")

# %%
df_processed_company_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7101 entries, 0 to 7100
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   first_name                      7101 non-null   object
#  1   middle_name                     700 non-null    object
#  2   last_name                       6626 non-null   object
#  3   job_title                       7057 non-null   object
#  4   person_city                     5674 non-null   object
#  5   person_state                    3508 non-null   object
#  6   person_country                  6576 non-null   object
#  7   email_pattern                   3859 non-null   object
#  8   homepage_base_url               7101 non-null   object
#  9   duration_in_current_job         1026 non-null   object
#  10  duration_in_current_company     997 non-null    object
#  11  company_logo_url                7051 non-null   object
#  12  company_logo_text               7101 non-null   object
#  13  company_name                    7101 non-null   object
#  14  relation_to_event               7101 non-null   object
#  15  event_url                       7101 non-null   object
#  16  company_revenue                 5833 non-null   object
#  17  n_employees                     7081 non-null   object
#  18  company_phone                   6196 non-null   object
#  19  company_founding_year           6325 non-null   float64
#  20  company_address                 5517 non-null   object
#  21  company_industry                7081 non-null   object
#  22  company_overview                7061 non-null   object
#  23  homepage_url                    7081 non-null   object
#  24  linkedin_company_url            5557 non-null   object
#  25  company_logo_url_on_event_page  7101 non-null   object
#  26  company_logo_match_flag         6828 non-null   object
#  27  email_address                   3663 non-null   object
# dtypes: float64(1), object(27)
# memory usage: 1.5+ MB

# %%
df_processed_company_people.head()
# Out:
#   first_name middle_name last_name                   job_title person_city  \
# 0    Cynthia         NaN   Battini              Indirect Buyer         NaN
# 1  Alexander         NaN   McClure            Public Relations      Austin
# 2  Alexander         NaN   McClure            Public Relations      Austin
# 3  Alexander         NaN   McClure            Public Relations      Austin
# 4      Nadir         NaN    Shaari  SEO Junior Account Manager      London
#
#   person_state person_country   email_pattern homepage_base_url  \
# 0          NaN         France             NaN      ariane.group
# 1           TX             US             NaN        amazon.com
# 2           TX             US             NaN        amazon.com
# 3           TX             US             NaN        amazon.com
# 4          NaN             GB  [first].[last]      artefact.com
#
#   duration_in_current_job  ...      company_phone company_founding_year  \
# 0                     NaN  ...  +33 5 57 20 86 25                2015.0
# 1                     NaN  ...     (206) 266-1000                2006.0
# 2                     NaN  ...     (206) 266-1000                2006.0
# 3                     NaN  ...     (206) 266-1000                2006.0
# 4                     NaN  ...  +33 1 79 72 45 45                2014.0
#
#                                      company_address  \
# 0  51-61 Route de Verneuil, Les Mureaux, Île-de-F...
# 1       2127 7th Ave., Seattle, Washington 98109, US
# 2       2127 7th Ave., Seattle, Washington 98109, US
# 3       2127 7th Ave., Seattle, Washington 98109, US
# 4      19 Rue Richer, Paris, Île-de-France 75009, FR
#
#                                  company_industry  \
# 0  Aviation and Aerospace Component Manufacturing
# 1                   IT Services and IT Consulting
# 2                   IT Services and IT Consulting
# 3                   IT Services and IT Consulting
# 4                Business Consulting and Services
#
#                                     company_overview  \
# 0  With roots reaching back more than 70 years in...
# 1  Launched in 2006, Amazon Web Services (AWS) be...
# 2  Launched in 2006, Amazon Web Services (AWS) be...
# 3  Launched in 2006, Amazon Web Services (AWS) be...
# 4  Artefact is a leading global consulting compan...
#
#                          homepage_url  \
# 0             http://www.ariane.group
# 1               http://aws.amazon.com
# 2               http://aws.amazon.com
# 3               http://aws.amazon.com
# 4  https://www.artefact.com/about-us/
#
#                                 linkedin_company_url  \
# 0  https://www.linkedin.com/company/arianegroup/a...
# 1  https://www.linkedin.com/company/amazon-web-se...
# 2  https://www.linkedin.com/company/amazon-web-se...
# 3  https://www.linkedin.com/company/amazon-web-se...
# 4  https://ae.linkedin.com/company/artefact-globa...
#
#                       company_logo_url_on_event_page company_logo_match_flag  \
# 0  https://www.space.org.sg/gstc/wp-content/uploa...                     yes
# 1  https://terrapinn-cdn.com/tres/pa-images/10817...                     yes
# 2  https://taskfilescsm.s3.amazonaws.com:443/uplo...                     yes
# 3  https://www.industrial-transformation.com//con...                     yes
# 4  https://www.digitalmarketing-conference.com/as...                     yes
#
#                email_address
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4  nadir.shaari@artefact.com
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Exporting Data to Database

# %%
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# Get the database credentials from environment variables
db_username = os.getenv('DB_USERNAME')
db_password = os.getenv('DB_PASSWORD')
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')

# %%
db_url = f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}'
# Create a database engine
engine = create_engine(db_url)

# %%
df_processed_company_people.to_sql('people_company', engine, if_exists='replace', index=False)
# Out:
# 101

# %%
df_processed_company_event.to_sql('event_company', engine, if_exists='replace', index=False)
# Out:
# 742
